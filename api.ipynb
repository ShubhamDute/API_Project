# %% [markdown]
# # Stock Market API Project
# Alpha Vantage API - "https://alpha-vantage.p.rapidapi.com/query"

# %%
import streamlit as st
api_key = st.secrets["API_KEY"]

# %% [markdown]
# # Search Endpoint

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

company = "State Bank of India"

querystring = {"datatype":"json","keywords":company,"function":"SYMBOL_SEARCH"}

headers = {
	"x-rapidapi-key": st.secrets["API_KEY"],
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data = response.json()
data
# Out:
# {'bestMatches': [{'1. symbol': 'SBIN.BSE',
#    '2. name': 'State Bank of India',
#    '3. type': 'Equity',
#    '4. region': 'India/Bombay',
#    '5. marketOpen': '09:15',
#    '6. marketClose': '15:30',
#    '7. timezone': 'UTC+5.5',
#    '8. currency': 'INR',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'SBKFF',
#    '2. name': 'State Bank of India',
#    '3. type': 'Equity',
#    '4. region': 'United States',
#    '5. marketOpen': '09:30',
#    '6. marketClose': '16:00',
#    '7. timezone': 'UTC-04',
#    '8. currency': 'USD',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'SID.FRK',
#    '2. name': 'State Bank of India',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'SBID.LON',
#    '2. name': 'State Bank of India GDR',
#    '3. type': 'Equity',
#    '4. region': 'United Kingdom',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '16:30',
#    '7. timezone': 'UTC+01',
#    '8. currency': 'USD',
#    '9. matchScore': '0.9048'}]}

# %%
import pandas as pd
symbols = pd.DataFrame(data["bestMatches"])
symbols
# Out:
#   1. symbol                  2. name 3. type       4. region 5. marketOpen  \
# 0  SBIN.BSE      State Bank of India  Equity    India/Bombay         09:15
# 1     SBKFF      State Bank of India  Equity   United States         09:30
# 2   SID.FRK      State Bank of India  Equity       Frankfurt         08:00
# 3  SBID.LON  State Bank of India GDR  Equity  United Kingdom         08:00
#
#   6. marketClose 7. timezone 8. currency 9. matchScore
# 0          15:30     UTC+5.5         INR        1.0000
# 1          16:00      UTC-04         USD        1.0000
# 2          20:00      UTC+02         EUR        1.0000
# 3          16:30      UTC+01         USD        0.9048

# %%
symbols.to_csv("SBIsymbols.csv", index=False)

# %% [markdown]
# # Daily Data for SBIN.BSE

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

symbols = "SBIN.BSE"

querystring = {"function":"TIME_SERIES_DAILY","symbol": symbols,"outputsize":"compact","datatype":"json"}

headers = {
	"x-rapidapi-key": st.secrets["API_KEY"],
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data = response.json()
data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'SBIN.BSE',
#   '3. Last Refreshed': '2025-11-13',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2025-11-13': {'1. open': '955.7000',
#    '2. high': '964.0000',
#    '3. low': '952.2000',
#    '4. close': '954.5500',
#    '5. volume': '968319'},
#   '2025-11-12': {'1. open': '958.0000',
#    '2. high': '961.5000',
#    '3. low': '951.0500',
#    '4. close': '957.3500',
#    '5. volume': '359053'},
#   '2025-11-11': {'1. open': '954.0000',
#    '2. high': '954.5000',
#    '3. low': '945.0500',
#    '4. close': '953.3000',
#    '5. volume': '1406920'},
#   '2025-11-10': {'1. open': '955.9500',
#    '2. high': '963.0000',
#    '3. low': '949.1500',
#    '4. close': '951.8500',
#    '5. volume': '387727'},
#   '2025-11-07': {'1. open': '959.9500',
#    '2. high': '964.5000',
#    '3. low': '944.0000',
#    '4. close': '955.9500',
#    '5. volume': '582333'},
#   '2025-11-06': {'1. open': '966.3500',
#    '2. high': '971.1500',
#    '3. low': '955.3000',
#    '4. close': '960.7500',
#    '5. volume': '1731058'},
#   '2025-11-04': {'1. open': '952.2500',
#    '2. high': '959.0000',
#    '3. low': '941.3500',
#    '4. close': '957.0500',
#    '5. volume': '948033'},
#   '2025-11-03': {'1. open': '938.5000',
#    '2. high': '953.1500',
#    '3. low': '937.8000',
#    '4. close': '950.2500',
#    '5. volume': '696733'},
#   '2025-10-31': {'1. open': '935.8000',
#    '2. high': '946.7000',
#    '3. low': '930.2500',
#    '4. close': '937.0000',
#    '5. volume': '780748'},
#   '2025-10-30': {'1. open': '940.0000',
#    '2. high': '944.6000',
#    '3. low': '932.9000',
#    '4. close': '934.1000',
#    '5. volume': '1338039'},
#   '2025-10-29': {'1. open': '932.6000',
#    '2. high': '941.6500',
#    '3. low': '930.3000',
#    '4. close': '939.8000',
#    '5. volume': '1089247'},
#   '2025-10-28': {'1. open': '923.2500',
#    '2. high': '935.9000',
#    '3. low': '917.8000',
#    '4. close': '930.2500',
#    '5. volume': '641738'},
#   '2025-10-27': {'1. open': '905.5000',
#    '2. high': '927.9000',
#    '3. low': '905.5000',
#    '4. close': '923.2500',
#    '5. volume': '392249'},
#   '2025-10-24': {'1. open': '911.4500',
#    '2. high': '914.2000',
#    '3. low': '900.8000',
#    '4. close': '904.4000',
#    '5. volume': '176431'},
#   '2025-10-23': {'1. open': '910.5500',
#    '2. high': '917.9000',
#    '3. low': '904.8000',
#    '4. close': '911.4500',
#    '5. volume': '1321998'},
#   '2025-10-20': {'1. open': '893.7000',
#    '2. high': '913.4000',
#    '3. low': '891.5500',
#    '4. close': '906.8500',
#    '5. volume': '835351'},
#   '2025-10-17': {'1. open': '886.2500',
#    '2. high': '894.6000',
#    '3. low': '882.6000',
#    '4. close': '889.3500',
#    '5. volume': '436700'},
#   '2025-10-16': {'1. open': '886.7500',
#    '2. high': '891.9000',
#    '3. low': '882.5000',
#    '4. close': '886.9000',
#    '5. volume': '1072968'},
#   '2025-10-15': {'1. open': '877.2000',
#    '2. high': '887.7500',
#    '3. low': '877.2000',
#    '4. close': '886.2000',
#    '5. volume': '564545'},
#   '2025-10-14': {'1. open': '883.0000',
#    '2. high': '884.5000',
#    '3. low': '872.1500',
#    '4. close': '876.9000',
#    '5. volume': '281465'},
#   '2025-10-13': {'1. open': '879.9500',
#    '2. high': '888.0500',
#    '3. low': '875.8000',
#    '4. close': '883.0000',
#    '5. volume': '620211'},
#   '2025-10-10': {'1. open': '861.2000',
#    '2. high': '883.7000',
#    '3. low': '861.2000',
#    '4. close': '880.7500',
#    '5. volume': '1334463'},
#   '2025-10-09': {'1. open': '861.2500',
#    '2. high': '865.6500',
#    '3. low': '858.2500',
#    '4. close': '862.1000',
#    '5. volume': '1347934'},
#   '2025-10-08': {'1. open': '866.1000',
#    '2. high': '868.0000',
#    '3. low': '857.3000',
#    '4. close': '858.0500',
#    '5. volume': '663817'},
#   '2025-10-07': {'1. open': '874.0500',
#    '2. high': '875.9500',
#    '3. low': '863.0500',
#    '4. close': '864.7000',
#    '5. volume': '715720'},
#   '2025-10-06': {'1. open': '868.9000',
#    '2. high': '874.9000',
#    '3. low': '862.5500',
#    '4. close': '874.0500',
#    '5. volume': '652683'},
#   '2025-10-03': {'1. open': '864.1500',
#    '2. high': '872.9500',
#    '3. low': '863.8500',
#    '4. close': '867.0500',
#    '5. volume': '783340'},
#   '2025-10-01': {'1. open': '872.6000',
#    '2. high': '876.5000',
#    '3. low': '862.4000',
#    '4. close': '864.0500',
#    '5. volume': '2208404'},
#   '2025-09-30': {'1. open': '870.4500',
#    '2. high': '877.5000',
#    '3. low': '867.8500',
#    '4. close': '872.5500',
#    '5. volume': '229410'},
#   '2025-09-29': {'1. open': '857.0500',
#    '2. high': '873.0000',
#    '3. low': '855.9000',
#    '4. close': '870.5000',
#    '5. volume': '533094'},
#   '2025-09-26': {'1. open': '861.0500',
#    '2. high': '864.1500',
#    '3. low': '852.5000',
#    '4. close': '857.0000',
#    '5. volume': '342057'},
#   '2025-09-25': {'1. open': '865.8500',
#    '2. high': '870.0500',
#    '3. low': '859.5500',
#    '4. close': '861.0500',
#    '5. volume': '804427'},
#   '2025-09-24': {'1. open': '875.2000',
#    '2. high': '880.4000',
#    '3. low': '864.5500',
#    '4. close': '865.8500',
#    '5. volume': '450238'},
#   '2025-09-23': {'1. open': '851.1000',
#    '2. high': '874.0000',
#    '3. low': '851.1000',
#    '4. close': '870.5000',
#    '5. volume': '388234'},
#   '2025-09-22': {'1. open': '862.9000',
#    '2. high': '868.0000',
#    '3. low': '853.9000',
#    '4. close': '855.0500',
#    '5. volume': '266104'},
#   '2025-09-19': {'1. open': '852.5000',
#    '2. high': '863.5000',
#    '3. low': '849.0500',
#    '4. close': '862.2500',
#    '5. volume': '552336'},
#   '2025-09-18': {'1. open': '856.7000',
#    '2. high': '860.9000',
#    '3. low': '851.0500',
#    '4. close': '854.4500',
#    '5. volume': '719272'},
#   '2025-09-17': {'1. open': '833.2500',
#    '2. high': '858.0000',
#    '3. low': '831.0000',
#    '4. close': '856.9500',
#    '5. volume': '1807341'},
#   '2025-09-16': {'1. open': '823.4000',
#    '2. high': '833.0000',
#    '3. low': '821.6000',
#    '4. close': '831.8000',
#    '5. volume': '368364'},
#   '2025-09-15': {'1. open': '823.3000',
#    '2. high': '828.0000',
#    '3. low': '821.4000',
#    '4. close': '824.9000',
#    '5. volume': '139666'},
#   '2025-09-12': {'1. open': '824.9000',
#    '2. high': '825.3500',
#    '3. low': '819.9000',
#    '4. close': '823.3000',
#    '5. volume': '297096'},
#   '2025-09-11': {'1. open': '816.2500',
#    '2. high': '825.5000',
#    '3. low': '816.2500',
#    '4. close': '823.8000',
#    '5. volume': '1044344'},
#   '2025-09-10': {'1. open': '811.2000',
#    '2. high': '824.5000',
#    '3. low': '810.2000',
#    '4. close': '818.3000',
#    '5. volume': '489810'},
#   '2025-09-09': {'1. open': '810.3500',
#    '2. high': '812.4500',
#    '3. low': '805.4000',
#    '4. close': '808.9500',
#    '5. volume': '170532'},
#   '2025-09-08': {'1. open': '807.1000',
#    '2. high': '813.5000',
#    '3. low': '807.1000',
#    '4. close': '809.0000',
#    '5. volume': '268859'},
#   '2025-09-05': {'1. open': '811.9000',
#    '2. high': '812.2000',
#    '3. low': '803.6000',
#    '4. close': '806.9500',
#    '5. volume': '272131'},
#   '2025-09-04': {'1. open': '816.7500',
#    '2. high': '816.7500',
#    '3. low': '807.8500',
#    '4. close': '809.3500',
#    '5. volume': '619504'},
#   '2025-09-03': {'1. open': '805.0000',
#    '2. high': '813.2000',
#    '3. low': '803.1000',
#    '4. close': '812.1500',
#    '5. volume': '187814'},
#   '2025-09-02': {'1. open': '809.9000',
#    '2. high': '810.5000',
#    '3. low': '802.9000',
#    '4. close': '803.9500',
#    '5. volume': '119021'},
#   '2025-09-01': {'1. open': '802.6500',
#    '2. high': '808.2500',
#    '3. low': '802.6500',
#    '4. close': '805.9000',
#    '5. volume': '164286'},
#   '2025-08-29': {'1. open': '802.0000',
#    '2. high': '807.0000',
#    '3. low': '798.6000',
#    '4. close': '802.3500',
#    '5. volume': '520632'},
#   '2025-08-28': {'1. open': '807.8000',
#    '2. high': '810.6000',
#    '3. low': '800.7000',
#    '4. close': '802.0500',
#    '5. volume': '146716'},
#   '2025-08-26': {'1. open': '815.8000',
#    '2. high': '815.8000',
#    '3. low': '806.5500',
#    '4. close': '807.8000',
#    '5. volume': '677825'},
#   '2025-08-25': {'1. open': '817.0000',
#    '2. high': '820.4500',
#    '3. low': '814.0000',
#    '4. close': '815.5000',
#    '5. volume': '373280'},
#   '2025-08-22': {'1. open': '825.5000',
#    '2. high': '825.9500',
#    '3. low': '815.5500',
#    '4. close': '816.1000',
#    '5. volume': '158755'},
#   '2025-08-21': {'1. open': '828.8000',
#    '2. high': '833.4500',
#    '3. low': '824.5000',
#    '4. close': '825.5500',
#    '5. volume': '138694'},
#   '2025-08-20': {'1. open': '829.8000',
#    '2. high': '831.5000',
#    '3. low': '826.9500',
#    '4. close': '828.8000',
#    '5. volume': '156440'},
#   '2025-08-19': {'1. open': '827.6500',
#    '2. high': '831.2500',
#    '3. low': '825.8500',
#    '4. close': '830.3500',
#    '5. volume': '289674'},
#   '2025-08-18': {'1. open': '831.3500',
#    '2. high': '835.2000',
#    '3. low': '825.3000',
#    '4. close': '827.0000',
#    '5. volume': '435823'},
#   '2025-08-14': {'1. open': '821.8500',
#    '2. high': '828.0000',
#    '3. low': '819.2000',
#    '4. close': '826.7000',
#    '5. volume': '492882'},
#   '2025-08-13': {'1. open': '823.4500',
#    '2. high': '824.9000',
#    '3. low': '820.5500',
#    '4. close': '822.1500',
#    '5. volume': '847012'},
#   '2025-08-12': {'1. open': '824.3000',
#    '2. high': '825.6000',
#    '3. low': '820.0000',
#    '4. close': '820.5500',
#    '5. volume': '784250'},
#   '2025-08-11': {'1. open': '807.0000',
#    '2. high': '824.9500',
#    '3. low': '807.0000',
#    '4. close': '824.3000',
#    '5. volume': '1141997'},
#   '2025-08-08': {'1. open': '805.0000',
#    '2. high': '807.9500',
#    '3. low': '790.1000',
#    '4. close': '804.5500',
#    '5. volume': '621304'},
#   '2025-08-07': {'1. open': '801.1000',
#    '2. high': '806.5000',
#    '3. low': '793.3000',
#    '4. close': '805.2500',
#    '5. volume': '188248'},
#   '2025-08-06': {'1. open': '801.0000',
#    '2. high': '810.0000',
#    '3. low': '799.0000',
#    '4. close': '805.1500',
#    '5. volume': '376366'},
#   '2025-08-05': {'1. open': '795.6500',
#    '2. high': '803.6500',
#    '3. low': '795.6500',
#    '4. close': '800.7000',
#    '5. volume': '512346'},
#   '2025-08-04': {'1. open': '795.0000',
#    '2. high': '797.4500',
#    '3. low': '786.5500',
#    '4. close': '795.6500',
#    '5. volume': '193850'},
#   '2025-08-01': {'1. open': '796.5000',
#    '2. high': '800.7500',
#    '3. low': '791.9500',
#    '4. close': '793.9500',
#    '5. volume': '234321'},
#   '2025-07-31': {'1. open': '796.6500',
#    '2. high': '803.6000',
#    '3. low': '792.4500',
#    '4. close': '796.4500',
#    '5. volume': '378571'},
#   '2025-07-30': {'1. open': '799.8500',
#    '2. high': '803.4000',
#    '3. low': '796.2500',
#    '4. close': '801.8500',
#    '5. volume': '154363'},
#   '2025-07-29': {'1. open': '795.3500',
#    '2. high': '800.2000',
#    '3. low': '793.1000',
#    '4. close': '798.9000',
#    '5. volume': '330118'},
#   '2025-07-28': {'1. open': '808.9500',
#    '2. high': '809.2000',
#    '3. low': '796.0000',
#    '4. close': '797.1500',
#    '5. volume': '389824'},
#   '2025-07-25': {'1. open': '814.3500',
#    '2. high': '819.0000',
#    '3. low': '805.5500',
#    '4. close': '806.5000',
#    '5. volume': '383923'},
#   '2025-07-24': {'1. open': '819.7500',
#    '2. high': '821.9500',
#    '3. low': '810.6500',
#    '4. close': '815.8500',
#    '5. volume': '323698'},
#   '2025-07-23': {'1. open': '815.2000',
#    '2. high': '825.0000',
#    '3. low': '811.4000',
#    '4. close': '820.7500',
#    '5. volume': '739975'},
#   '2025-07-22': {'1. open': '829.0000',
#    '2. high': '829.0000',
#    '3. low': '814.0000',
#    '4. close': '815.0000',
#    '5. volume': '174364'},
#   '2025-07-21': {'1. open': '823.5000',
#    '2. high': '827.4000',
#    '3. low': '817.9500',
#    '4. close': '824.2000',
#    '5. volume': '258166'},
#   '2025-07-18': {'1. open': '832.4000',
#    '2. high': '832.4000',
#    '3. low': '820.0500',
#    '4. close': '823.3000',
#    '5. volume': '256301'},
#   '2025-07-17': {'1. open': '839.0000',
#    '2. high': '842.3000',
#    '3. low': '826.1500',
#    '4. close': '828.6000',
#    '5. volume': '624129'},
#   '2025-07-16': {'1. open': '816.5000',
#    '2. high': '834.0000',
#    '3. low': '815.1500',
#    '4. close': '831.5500',
#    '5. volume': '1238621'},
#   '2025-07-15': {'1. open': '810.2000',
#    '2. high': '821.0000',
#    '3. low': '810.2000',
#    '4. close': '816.7500',
#    '5. volume': '460084'},
#   '2025-07-14': {'1. open': '810.4000',
#    '2. high': '815.6000',
#    '3. low': '808.0000',
#    '4. close': '809.3000',
#    '5. volume': '435542'},
#   '2025-07-11': {'1. open': '808.0000',
#    '2. high': '812.6000',
#    '3. low': '804.5000',
#    '4. close': '808.5000',
#    '5. volume': '227573'},
#   '2025-07-10': {'1. open': '812.0000',
#    '2. high': '815.5000',
#    '3. low': '807.0500',
#    '4. close': '808.0000',
#    '5. volume': '174968'},
#   '2025-07-09': {'1. open': '810.0000',
#    '2. high': '812.2500',
#    '3. low': '809.1000',
#    '4. close': '810.8500',
#    '5. volume': '176144'},
#   '2025-07-08': {'1. open': '808.9500',
#    '2. high': '813.8500',
#    '3. low': '805.5000',
#    '4. close': '812.8000',
#    '5. volume': '573527'},
#   '2025-07-07': {'1. open': '812.8000',
#    '2. high': '812.8000',
#    '3. low': '805.2000',
#    '4. close': '806.9500',
#    '5. volume': '116638'},
#   '2025-07-04': {'1. open': '810.2500',
#    '2. high': '813.5000',
#    '3. low': '804.2000',
#    '4. close': '811.8500',
#    '5. volume': '359322'},
#   '2025-07-03': {'1. open': '813.0000',
#    '2. high': '815.0000',
#    '3. low': '806.0000',
#    '4. close': '807.1000',
#    '5. volume': '429112'},
#   '2025-07-02': {'1. open': '820.7000',
#    '2. high': '824.3500',
#    '3. low': '809.1000',
#    '4. close': '813.2000',
#    '5. volume': '193280'},
#   '2025-07-01': {'1. open': '820.3500',
#    '2. high': '824.9500',
#    '3. low': '813.2500',
#    '4. close': '820.2500',
#    '5. volume': '633178'},
#   '2025-06-30': {'1. open': '808.9500',
#    '2. high': '821.0000',
#    '3. low': '807.0500',
#    '4. close': '820.3500',
#    '5. volume': '478069'},
#   '2025-06-27': {'1. open': '806.0000',
#    '2. high': '809.5000',
#    '3. low': '802.4000',
#    '4. close': '805.4000',
#    '5. volume': '477274'},
#   '2025-06-26': {'1. open': '802.7000',
#    '2. high': '803.4500',
#    '3. low': '791.5000',
#    '4. close': '797.0000',
#    '5. volume': '478368'},
#   '2025-06-25': {'1. open': '799.0000',
#    '2. high': '805.0000',
#    '3. low': '796.1000',
#    '4. close': '800.1000',
#    '5. volume': '197275'},
#   '2025-06-24': {'1. open': '798.5000',
#    '2. high': '806.5000',
#    '3. low': '793.6000',
#    '4. close': '795.2500',
#    '5. volume': '937612'},
#   '2025-06-23': {'1. open': '790.2000',
#    '2. high': '794.6000',
#    '3. low': '788.4500',
#    '4. close': '790.1500',
#    '5. volume': '212782'},
#   '2025-06-20': {'1. open': '787.9500',
#    '2. high': '799.1000',
#    '3. low': '786.3000',
#    '4. close': '796.0000',
#    '5. volume': '224991'},
#   '2025-06-19': {'1. open': '792.8500',
#    '2. high': '793.2000',
#    '3. low': '781.5000',
#    '4. close': '784.7000',
#    '5. volume': '235832'}}}

# %%
stock_df = pd.DataFrame(data["Time Series (Daily)"]).T
stock_df
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2025-11-13  955.7000  964.0000  952.2000  954.5500    968319
# 2025-11-12  958.0000  961.5000  951.0500  957.3500    359053
# 2025-11-11  954.0000  954.5000  945.0500  953.3000   1406920
# 2025-11-10  955.9500  963.0000  949.1500  951.8500    387727
# 2025-11-07  959.9500  964.5000  944.0000  955.9500    582333
# ...              ...       ...       ...       ...       ...
# 2025-06-25  799.0000  805.0000  796.1000  800.1000    197275
# 2025-06-24  798.5000  806.5000  793.6000  795.2500    937612
# 2025-06-23  790.2000  794.6000  788.4500  790.1500    212782
# 2025-06-20  787.9500  799.1000  786.3000  796.0000    224991
# 2025-06-19  792.8500  793.2000  781.5000  784.7000    235832
#
# [100 rows x 5 columns]

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 2025-11-13 to 2025-06-19
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   1. open    100 non-null    object
#  1   2. high    100 non-null    object
#  2   3. low     100 non-null    object
#  3   4. close   100 non-null    object
#  4   5. volume  100 non-null    object
# dtypes: object(5)
# memory usage: 4.7+ KB

# %%
# convert into float data type
stock_df = stock_df.astype(float)
stock_df.dtypes
# Out:
# 1. open      float64
# 2. high      float64
# 3. low       float64
# 4. close     float64
# 5. volume    float64
# dtype: object

# %%
stock_df.index
# Out:
# Index(['2025-11-13', '2025-11-12', '2025-11-11', '2025-11-10', '2025-11-07',
#        '2025-11-06', '2025-11-04', '2025-11-03', '2025-10-31', '2025-10-30',
#        '2025-10-29', '2025-10-28', '2025-10-27', '2025-10-24', '2025-10-23',
#        '2025-10-20', '2025-10-17', '2025-10-16', '2025-10-15', '2025-10-14',
#        '2025-10-13', '2025-10-10', '2025-10-09', '2025-10-08', '2025-10-07',
#        '2025-10-06', '2025-10-03', '2025-10-01', '2025-09-30', '2025-09-29',
#        '2025-09-26', '2025-09-25', '2025-09-24', '2025-09-23', '2025-09-22',
#        '2025-09-19', '2025-09-18', '2025-09-17', '2025-09-16', '2025-09-15',
#        '2025-09-12', '2025-09-11', '2025-09-10', '2025-09-09', '2025-09-08',
#        '2025-09-05', '2025-09-04', '2025-09-03', '2025-09-02', '2025-09-01',
#        '2025-08-29', '2025-08-28', '2025-08-26', '2025-08-25', '2025-08-22',
#        '2025-08-21', '2025-08-20', '2025-08-19', '2025-08-18', '2025-08-14',
#        '2025-08-13', '2025-08-12', '2025-08-11', '2025-08-08', '2025-08-07',
#        '2025-08-06', '2025-08-05', '2025-08-04', '2025-08-01', '2025-07-31',
#        '2025-07-30', '2025-07-29', '2025-07-28', '2025-07-25', '2025-07-24',
#        '2025-07-23', '2025-07-22', '2025-07-21', '2025-07-18', '2025-07-17',
#        '2025-07-16', '2025-07-15', '2025-07-14', '2025-07-11', '2025-07-10',
#        '2025-07-09', '2025-07-08', '2025-07-07', '2025-07-04', '2025-07-03',
#        '2025-07-02', '2025-07-01', '2025-06-30', '2025-06-27', '2025-06-26',
#        '2025-06-25', '2025-06-24', '2025-06-23', '2025-06-20', '2025-06-19'],
#       dtype='object')

# %%
stock_df.index = pd.to_datetime(stock_df.index)
stock_df.index
# Out:
# DatetimeIndex(['2025-11-13', '2025-11-12', '2025-11-11', '2025-11-10',
#                '2025-11-07', '2025-11-06', '2025-11-04', '2025-11-03',
#                '2025-10-31', '2025-10-30', '2025-10-29', '2025-10-28',
#                '2025-10-27', '2025-10-24', '2025-10-23', '2025-10-20',
#                '2025-10-17', '2025-10-16', '2025-10-15', '2025-10-14',
#                '2025-10-13', '2025-10-10', '2025-10-09', '2025-10-08',
#                '2025-10-07', '2025-10-06', '2025-10-03', '2025-10-01',
#                '2025-09-30', '2025-09-29', '2025-09-26', '2025-09-25',
#                '2025-09-24', '2025-09-23', '2025-09-22', '2025-09-19',
#                '2025-09-18', '2025-09-17', '2025-09-16', '2025-09-15',
#                '2025-09-12', '2025-09-11', '2025-09-10', '2025-09-09',
#                '2025-09-08', '2025-09-05', '2025-09-04', '2025-09-03',
#                '2025-09-02', '2025-09-01', '2025-08-29', '2025-08-28',
#                '2025-08-26', '2025-08-25', '2025-08-22', '2025-08-21',
#                '2025-08-20', '2025-08-19', '2025-08-18', '2025-08-14',
#                '2025-08-13', '2025-08-12', '2025-08-11', '2025-08-08',
#                '2025-08-07', '2025-08-06', '2025-08-05', '2025-08-04',
#                '2025-08-01', '2025-07-31', '2025-07-30', '2025-07-29',
#                '2025-07-28', '2025-07-25', '2025-07-24', '2025-07-23',
#                '2025-07-22', '2025-07-21', '2025-07-18', '2025-07-17',
#                '2025-07-16', '2025-07-15', '2025-07-14', '2025-07-11',
#                '2025-07-10', '2025-07-09', '2025-07-08', '2025-07-07',
#                '2025-07-04', '2025-07-03', '2025-07-02', '2025-07-01',
#                '2025-06-30', '2025-06-27', '2025-06-26', '2025-06-25',
#                '2025-06-24', '2025-06-23', '2025-06-20', '2025-06-19'],
#               dtype='datetime64[ns]', freq=None)

# %%
stock_df.index
# Out:
# DatetimeIndex(['2025-11-13', '2025-11-12', '2025-11-11', '2025-11-10',
#                '2025-11-07', '2025-11-06', '2025-11-04', '2025-11-03',
#                '2025-10-31', '2025-10-30', '2025-10-29', '2025-10-28',
#                '2025-10-27', '2025-10-24', '2025-10-23', '2025-10-20',
#                '2025-10-17', '2025-10-16', '2025-10-15', '2025-10-14',
#                '2025-10-13', '2025-10-10', '2025-10-09', '2025-10-08',
#                '2025-10-07', '2025-10-06', '2025-10-03', '2025-10-01',
#                '2025-09-30', '2025-09-29', '2025-09-26', '2025-09-25',
#                '2025-09-24', '2025-09-23', '2025-09-22', '2025-09-19',
#                '2025-09-18', '2025-09-17', '2025-09-16', '2025-09-15',
#                '2025-09-12', '2025-09-11', '2025-09-10', '2025-09-09',
#                '2025-09-08', '2025-09-05', '2025-09-04', '2025-09-03',
#                '2025-09-02', '2025-09-01', '2025-08-29', '2025-08-28',
#                '2025-08-26', '2025-08-25', '2025-08-22', '2025-08-21',
#                '2025-08-20', '2025-08-19', '2025-08-18', '2025-08-14',
#                '2025-08-13', '2025-08-12', '2025-08-11', '2025-08-08',
#                '2025-08-07', '2025-08-06', '2025-08-05', '2025-08-04',
#                '2025-08-01', '2025-07-31', '2025-07-30', '2025-07-29',
#                '2025-07-28', '2025-07-25', '2025-07-24', '2025-07-23',
#                '2025-07-22', '2025-07-21', '2025-07-18', '2025-07-17',
#                '2025-07-16', '2025-07-15', '2025-07-14', '2025-07-11',
#                '2025-07-10', '2025-07-09', '2025-07-08', '2025-07-07',
#                '2025-07-04', '2025-07-03', '2025-07-02', '2025-07-01',
#                '2025-06-30', '2025-06-27', '2025-06-26', '2025-06-25',
#                '2025-06-24', '2025-06-23', '2025-06-20', '2025-06-19'],
#               dtype='datetime64[ns]', freq=None)

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 100 entries, 2025-11-13 to 2025-06-19
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   1. open    100 non-null    float64
#  1   2. high    100 non-null    float64
#  2   3. low     100 non-null    float64
#  3   4. close   100 non-null    float64
#  4   5. volume  100 non-null    float64
# dtypes: float64(5)
# memory usage: 4.7 KB

# %%
stock_df
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# 2025-11-13   955.70    964.0  952.20    954.55   968319.0
# 2025-11-12   958.00    961.5  951.05    957.35   359053.0
# 2025-11-11   954.00    954.5  945.05    953.30  1406920.0
# 2025-11-10   955.95    963.0  949.15    951.85   387727.0
# 2025-11-07   959.95    964.5  944.00    955.95   582333.0
# ...             ...      ...     ...       ...        ...
# 2025-06-25   799.00    805.0  796.10    800.10   197275.0
# 2025-06-24   798.50    806.5  793.60    795.25   937612.0
# 2025-06-23   790.20    794.6  788.45    790.15   212782.0
# 2025-06-20   787.95    799.1  786.30    796.00   224991.0
# 2025-06-19   792.85    793.2  781.50    784.70   235832.0
#
# [100 rows x 5 columns]

# %%
stock_df.to_csv("SBIN.csv",index=False)

# %% [markdown]
# # Visualize above using plotly chart

# %%
import plotly.graph_objects as go
fig = go.Figure(data= [
    go.Candlestick(
         x = stock_df.index,
         open = stock_df["1. open"],
         high = stock_df["2. high"],
         low = stock_df["3. low"],
         close = stock_df["4. close"]
    )
])
fig.update_layout(
    height = 800,
    width = 1200

)
fig.show()

# %% [markdown]
# # Build a class to fetch any stock market data

# %%
import streamlit as st
import requests
import pandas as pd
import plotly.graph_objects as go

class StockAPI:

    def __init__(self):
        self.url = "https://alpha-vantage.p.rapidapi.com/query"
        self.headers = {
            "x-rapidapi-key": st.secrets["API_KEY"],
            "x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
        }

    def get_symbols(self, company: str) -> pd.DataFrame:
        querystring = {"datatype":"json","keywords":company,"function":"SYMBOL_SEARCH"}
        response = requests.get(self.url, headers=self.headers, params=querystring)
        response.raise_for_status()
        data = response.json()
        search_df = pd.DataFrame(data["bestMatches"])
        return search_df
    
    def get_daily_prices(self, symbol: str) -> pd.DataFrame:
        querystring = {"function":"TIME_SERIES_DAILY","symbol":symbol,"outputsize":"compact","datatype":"json"}
        response = requests.get(url = self.url, headers=self.headers, params=querystring)
        response.raise_for_status()
        data = response.json()
        price_df = pd.DataFrame(data["Time Series (Daily)"]).T
        price_df = price_df.astype(float)
        price_df.index = pd.to_datetime(price_df.index)
        return price_df
    
    def plot_candlestick(self, stock_df: pd.DataFrame) -> go.Figure:
        fig = go.Figure(data = [
            go.Candlestick(
                x = stock_df.index,
                open = stock_df["1. open"],
                high = stock_df["2. high"],
                low = stock_df["3. low"],
                close = stock_df["4. close"]
            )
        ])

        fig.update_layout(
            height = 800,
            width = 1200
        )
        return fig

# %%
client = StockAPI()

# %%
client.get_symbols(company = "HDFC bank")
# Out:
#       1. symbol            2. name 3. type         4. region 5. marketOpen  \
# 0           HDB      HDFC Bank Ltd  Equity     United States         09:30
# 1  HDFCBANK.BSE  HDFC Bank Limited  Equity      India/Bombay         09:15
# 2    H1DB34.SAO  HDFC Bank Limited  Equity  Brazil/Sao Paolo         10:00
# 3      HDFA.FRK  HDFC Bank Limited  Equity         Frankfurt         08:00
#
#   6. marketClose 7. timezone 8. currency 9. matchScore
# 0          16:00      UTC-04         USD        0.8182
# 1          15:30     UTC+5.5         INR        0.8000
# 2          17:30      UTC-03         BRL        0.6923
# 3          20:00      UTC+02         EUR        0.6923

# %%
hdfc_prices =  client.get_daily_prices(symbol = "HDFCBANK.BSE")
hdfc_prices
# Out:
#             1. open  2. high   3. low  4. close  5. volume
# 2025-11-13   983.75   990.30   982.50    986.80  1462892.0
# 2025-11-12  1000.00  1000.00   987.35    989.45   493627.0
# 2025-11-11   985.00   993.25   978.15    991.70   235562.0
# 2025-11-10   980.00   991.75   980.00    984.35   501924.0
# 2025-11-07   984.30   984.80   974.55    982.90   611248.0
# ...             ...      ...      ...       ...        ...
# 2025-06-25  1972.35  1982.00  1962.90   1980.20   253714.0
# 2025-06-24  1960.20  1978.85  1955.25   1960.50  4930658.0
# 2025-06-23  1946.40  1957.50  1942.10   1947.80   463306.0
# 2025-06-20  1934.50  1969.15  1931.80   1965.70   643926.0
# 2025-06-19  1930.25  1946.00  1927.00   1934.80   305440.0
#
# [100 rows x 5 columns]

# %%
fig = client.plot_candlestick(hdfc_prices)
fig.show()

# %%
client.get_symbols("Godrej")
# Out:
#         1. symbol                           2. name 3. type     4. region  \
# 0    GODREJCP.BSE     GODREJ CONSUMER PRODUCTS LTD.  Equity  India/Bombay
# 1   GODREJIND.BSE            GODREJ INDUSTRIES LTD.  Equity  India/Bombay
# 2  GODREJAGRO.BSE                Godrej Agrovet Ltd  Equity  India/Bombay
# 3  GODREJPROP.BSE             Godrej Properties Ltd  Equity  India/Bombay
# 4      540743.BSE            Godrej Agrovet Limited  Equity  India/Bombay
# 5      532424.BSE  Godrej Consumer Products Limited  Equity  India/Bombay
#
#   5. marketOpen 6. marketClose 7. timezone 8. currency 9. matchScore
# 0         09:15          15:30     UTC+5.5         INR        0.7059
# 1         09:15          15:30     UTC+5.5         INR        0.6667
# 2         09:15          15:30     UTC+5.5         INR        0.6316
# 3         09:15          15:30     UTC+5.5         INR        0.6316
# 4         09:15          15:30     UTC+5.5         INR        0.4286
# 5         09:15          15:30     UTC+5.5         INR        0.3158

# %%
Godrej_prices = client.get_daily_prices("GODREJIND.BSE")
Godrej_prices
# Out:
#             1. open  2. high   3. low  4. close   5. volume
# 2025-11-14  1062.50  1074.15  1052.55   1065.05  11218686.0
# 2025-11-13  1066.40  1075.00  1060.30   1062.45      2401.0
# 2025-11-12  1069.85  1070.10  1037.80   1067.95      6076.0
# 2025-11-11  1072.70  1077.00  1052.55   1069.90      2174.0
# 2025-11-10  1056.65  1083.90  1048.90   1060.10      5532.0
# ...             ...      ...      ...       ...         ...
# 2025-07-02  1200.00  1217.10  1148.20   1157.10     27686.0
# 2025-07-01  1254.95  1257.90  1201.25   1207.65     10385.0
# 2025-06-30  1249.65  1273.25  1238.95   1247.20      6189.0
# 2025-06-27  1244.95  1257.85  1241.00   1248.40      6093.0
# 2025-06-26  1264.95  1264.95  1238.80   1248.25      4377.0
#
# [100 rows x 5 columns]

# %%
Godrej_prices.to_csv("godrejind.csv")

# %%
fig = client.plot_candlestick (Godrej_prices)
fig.show()
